# %%
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = r"E:\projects\OCR_Project\Gemini_Generated_Image_220nkx220nkx220n-min.png"

# %%
image = Image.open(img_path)

# %%
text = pytesseract.image_to_string(image)

# %%
plt.imshow(image)

# %%
text
# Out:
# 'W YORK STATE™ |\n\nWw VER LICENSE\n0123 456 789 _ dass D ‘\nMOTORIST\n\nMICHAEL, MATTHEW #SAMPLE\n\n2345 ANYWHERE STREET\nYOUR CITY, NY 12345\n\nSex M Height 5\'-08" Eyes BRC\n\n008 10/90/1972\n\nEqires 10/30/2025 © ae iad Aaa.\n| ENONE i il\n\nRNONE AY)\nissued 10/30/2017 Js Wa a a\n\n'
